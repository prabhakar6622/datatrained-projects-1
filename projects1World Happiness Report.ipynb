# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df=pd.read_csv('C:/Users/Jai Mata Di/Desktop/happiness_score_dataset.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
pd.set_option('display.max_row',None)
df
# Out:
#                       Country                           Region  \
# 0                 Switzerland                   Western Europe
# 1                     Iceland                   Western Europe
# 2                     Denmark                   Western Europe
# 3                      Norway                   Western Europe
# 4                      Canada                    North America
# 5                     Finland                   Western Europe
# 6                 Netherlands                   Western Europe
# 7                      Sweden                   Western Europe
# 8                 New Zealand        Australia and New Zealand
# 9                   Australia        Australia and New Zealand
# 10                     Israel  Middle East and Northern Africa
# 11                 Costa Rica      Latin America and Caribbean
# 12                    Austria                   Western Europe
# 13                     Mexico      Latin America and Caribbean
# ...

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.title('null values')
plt.show()

# %%
df.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
corr_mat=df.corr()
#size
plt.figure(figsize=[20,20])
sns.heatmap(corr_mat,annot=True)
plt.title("correalationMatrix")
plt.show()

# %%
type(corr_mat)
# Out:
# pandas.core.frame.DataFrame

# %%
data_2015=pd.read_csv('C:/Users/Jai Mata Di/Desktop/happiness_score_dataset.csv')

# %%
data_2015.head
# Out:
# <bound method NDFrame.head of                       Country                           Region  \
# 0                 Switzerland                   Western Europe
# 1                     Iceland                   Western Europe
# 2                     Denmark                   Western Europe
# 3                      Norway                   Western Europe
# 4                      Canada                    North America
# 5                     Finland                   Western Europe
# 6                 Netherlands                   Western Europe
# 7                      Sweden                   Western Europe
# 8                 New Zealand        Australia and New Zealand
# 9                   Australia        Australia and New Zealand
# 10                     Israel  Middle East and Northern Africa
# 11                 Costa Rica      Latin America and Caribbean
# 12                    Austria                   Western Europe
# ...

# %%
data_2016=pd.read_csv('C:/Users/Jai Mata Di/Desktop/happiness_score_dataset.csv')
data_2016.head
# Out:
# <bound method NDFrame.head of                       Country                           Region  \
# 0                 Switzerland                   Western Europe
# 1                     Iceland                   Western Europe
# 2                     Denmark                   Western Europe
# 3                      Norway                   Western Europe
# 4                      Canada                    North America
# 5                     Finland                   Western Europe
# 6                 Netherlands                   Western Europe
# 7                      Sweden                   Western Europe
# 8                 New Zealand        Australia and New Zealand
# 9                   Australia        Australia and New Zealand
# 10                     Israel  Middle East and Northern Africa
# 11                 Costa Rica      Latin America and Caribbean
# 12                    Austria                   Western Europe
# ...

# %%
def show_nulls(df):
    total_nan = df.isnull().sum()
    perc_nan = total_nan/len(df)*100
    
    return total_nan, perc_nan

# %%
print('Total nul', show_nulls(df=df)[0])
# Out:
# Total nul Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
print('Percentage of null', show_nulls(df=df)[1])
# Out:
# Percentage of null Country                          0.0
# Region                           0.0
# Happiness Rank                   0.0
# Happiness Score                  0.0
# Standard Error                   0.0
# Economy (GDP per Capita)         0.0
# Family                           0.0
# Health (Life Expectancy)         0.0
# Freedom                          0.0
# Trust (Government Corruption)    0.0
# Generosity                       0.0
# Dystopia Residual                0.0
# dtype: float64

# %%
df.shape
# Out:
# (158, 12)

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
sns.lmplot(x="Family", y = 'Health (Life Expectancy)', data = df)

# %%
sns.lmplot(x="Happiness Score", y = 'Trust (Government Corruption)', data = df)

# %%
sns.heatmap(df.corr(), cmap='Reds')
# Out:
# <AxesSubplot:>

# %%
df.groupby(['Country']).max()['Happiness Score']
# Out:
# Country
# Afghanistan                 3.575
# Albania                     4.959
# Algeria                     5.605
# Angola                      4.033
# Argentina                   6.574
# Armenia                     4.350
# Australia                   7.284
# Austria                     7.200
# Azerbaijan                  5.212
# Bahrain                     5.960
# Bangladesh                  4.694
# Belarus                     5.813
# Belgium                     6.937
# Benin                       3.340
# Bhutan                      5.253
# Bolivia                     5.890
# Bosnia and Herzegovina      4.949
# Botswana                    4.332
# Brazil                      6.983
# Bulgaria                    4.218
# Burkina Faso                3.587
# Burundi                     2.905
# Cambodia                    3.819
# Cameroon                    4.252
# Canada                      7.427
# Central African Republic    3.678
# Chad                        3.667
# ...

# %%
df.groupby(['Country']).max()['Happiness Rank']
# Out:
# Country
# Afghanistan                 153
# Albania                      95
# Algeria                      68
# Angola                      137
# Argentina                    30
# Armenia                     127
# Australia                    10
# Austria                      13
# Azerbaijan                   80
# Bahrain                      49
# Bangladesh                  109
# Belarus                      59
# Belgium                      19
# Benin                       155
# Bhutan                       79
# Bolivia                      51
# Bosnia and Herzegovina       96
# Botswana                    128
# Brazil                       16
# Bulgaria                    134
# Burkina Faso                152
# Burundi                     157
# Cambodia                    145
# Cameroon                    133
# Canada                        5
# Central African Republic    148
# Chad                        149
# Chile                        27
# China                        84
# ...

# %%
df.groupby(['Country']).max()['Standard Error']
# Out:
# Country
# Afghanistan                 0.03084
# Albania                     0.05013
# Algeria                     0.05099
# Angola                      0.04758
# Argentina                   0.04612
# Armenia                     0.04763
# Australia                   0.04083
# Austria                     0.03751
# Azerbaijan                  0.03363
# Bahrain                     0.05412
# Bangladesh                  0.03077
# Belarus                     0.03938
# Belgium                     0.03595
# Benin                       0.03656
# Bhutan                      0.03225
# Bolivia                     0.05642
# Bosnia and Herzegovina      0.06913
# Botswana                    0.04934
# Brazil                      0.04076
# Bulgaria                    0.04828
# Burkina Faso                0.04324
# Burundi                     0.08658
# Cambodia                    0.05069
# Cameroon                    0.04678
# Canada                      0.03553
# Central African Republic    0.06112
# ...

# %%
df.groupby(['Country']).max()['Economy (GDP per Capita)']
# Out:
# Country
# Afghanistan                 0.31982
# Albania                     0.87867
# Algeria                     0.93929
# Angola                      0.75778
# Argentina                   1.05351
# Armenia                     0.76821
# Australia                   1.33358
# Austria                     1.33723
# Azerbaijan                  1.02389
# Bahrain                     1.32376
# Bangladesh                  0.39753
# Belarus                     1.03192
# Belgium                     1.30782
# Benin                       0.28665
# Bhutan                      0.77042
# Bolivia                     0.68133
# Bosnia and Herzegovina      0.83223
# Botswana                    0.99355
# Brazil                      0.98124
# Bulgaria                    1.01216
# Burkina Faso                0.25812
# Burundi                     0.01530
# Cambodia                    0.46038
# Cameroon                    0.42250
# Canada                      1.32629
# Central African Republic    0.07850
# ...

# %%
df.groupby(['Country']).max()['Family']
# Out:
# Country
# Afghanistan                 0.30285
# Albania                     0.80434
# Algeria                     1.07772
# Angola                      0.86040
# Argentina                   1.24823
# Armenia                     0.77711
# Australia                   1.30923
# Austria                     1.29704
# Azerbaijan                  0.93793
# Bahrain                     1.21624
# Bangladesh                  0.43106
# Belarus                     1.23289
# Belgium                     1.28566
# Benin                       0.35386
# Bhutan                      1.10395
# Bolivia                     0.97841
# Bosnia and Herzegovina      0.91916
# Botswana                    1.10464
# Brazil                      1.23287
# Bulgaria                    1.10614
# Burkina Faso                0.85188
# Burundi                     0.41587
# Cambodia                    0.62736
# Cameroon                    0.88767
# Canada                      1.32261
# Central African Republic    0.00000
# ...

# %%
df.groupby(['Country']).max()['Health (Life Expectancy)']
# Out:
# Country
# Afghanistan                 0.30335
# Albania                     0.81325
# Algeria                     0.61766
# Angola                      0.16683
# Argentina                   0.78723
# Armenia                     0.72990
# Australia                   0.93156
# Austria                     0.89042
# Azerbaijan                  0.64045
# Bahrain                     0.74716
# Bangladesh                  0.60164
# Belarus                     0.73608
# Belgium                     0.89667
# Benin                       0.31910
# Bhutan                      0.57407
# Bolivia                     0.53920
# Bosnia and Herzegovina      0.79081
# Botswana                    0.04776
# Brazil                      0.69702
# Bulgaria                    0.76649
# Burkina Faso                0.27125
# Burundi                     0.22396
# Cambodia                    0.61114
# Cameroon                    0.23402
# Canada                      0.90563
# Central African Republic    0.06699
# ...

# %%
df.groupby(['Country']).max()['Freedom']
# Out:
# Country
# Afghanistan                 0.23414
# Albania                     0.35733
# Algeria                     0.28579
# Angola                      0.10384
# Argentina                   0.44974
# Armenia                     0.19847
# Australia                   0.65124
# Austria                     0.62433
# Azerbaijan                  0.37030
# Bahrain                     0.45492
# Bangladesh                  0.40820
# Belarus                     0.37938
# Belgium                     0.58450
# Benin                       0.48450
# Bhutan                      0.53206
# Bolivia                     0.57414
# Bosnia and Herzegovina      0.09245
# Botswana                    0.49495
# Brazil                      0.49049
# Bulgaria                    0.30587
# Burkina Faso                0.39493
# Burundi                     0.11850
# Cambodia                    0.66246
# Cameroon                    0.49309
# Canada                      0.63297
# Central African Republic    0.48879
# ...

# %%
df.groupby(['Country']).max()['Trust (Government Corruption)']
# Out:
# Country
# Afghanistan                 0.09719
# Albania                     0.06413
# Algeria                     0.17383
# Angola                      0.07122
# Argentina                   0.08484
# Armenia                     0.03900
# Australia                   0.35637
# Austria                     0.18676
# Azerbaijan                  0.16065
# Bahrain                     0.30600
# Bangladesh                  0.12569
# Belarus                     0.19090
# Belgium                     0.22540
# Benin                       0.08010
# Bhutan                      0.15445
# Bolivia                     0.08800
# Bosnia and Herzegovina      0.00227
# Botswana                    0.12474
# Brazil                      0.17521
# Bulgaria                    0.00872
# Burkina Faso                0.12832
# Burundi                     0.10062
# Cambodia                    0.07247
# Cameroon                    0.05786
# Canada                      0.32957
# Central African Republic    0.08289
# ...

# %%
df.groupby(['Country']).max()['Generosity']
# Out:
# Country
# Afghanistan                 0.36510
# Albania                     0.14272
# Algeria                     0.07822
# Angola                      0.12344
# Argentina                   0.11451
# Armenia                     0.07855
# Australia                   0.43562
# Austria                     0.33088
# Azerbaijan                  0.07799
# Bahrain                     0.17362
# Bangladesh                  0.21222
# Belarus                     0.11046
# Belgium                     0.22250
# Benin                       0.18260
# Bhutan                      0.47998
# Bolivia                     0.20536
# Bosnia and Herzegovina      0.24808
# Botswana                    0.10461
# Brazil                      0.14574
# Bulgaria                    0.11921
# Burkina Faso                0.21747
# Burundi                     0.19727
# Cambodia                    0.40359
# Cameroon                    0.20618
# Canada                      0.45811
# Central African Republic    0.23835
# ...

# %%
df.groupby(['Country']).max()['Dystopia Residual']
# Out:
# Country
# Afghanistan                 1.95210
# Albania                     1.89894
# Algeria                     2.43209
# Angola                      1.94939
# Argentina                   2.83600
# Armenia                     1.75873
# Australia                   2.26646
# Austria                     2.53320
# Azerbaijan                  2.00073
# Bahrain                     1.73797
# Bangladesh                  2.51767
# Belarus                     2.13090
# Belgium                     2.41484
# Benin                       1.63328
# Bhutan                      1.63794
# Bolivia                     2.82334
# Bosnia and Herzegovina      2.06367
# Botswana                    1.46181
# Brazil                      3.26001
# Bulgaria                    0.89991
# Burkina Faso                1.46494
# Burundi                     1.83302
# Cambodia                    0.98195
# Cameroon                    1.95071
# Canada                      2.45176
# Central African Republic    2.72230
# ...

# %%
df
# Out:
#                       Country                           Region  \
# 0                 Switzerland                   Western Europe
# 1                     Iceland                   Western Europe
# 2                     Denmark                   Western Europe
# 3                      Norway                   Western Europe
# 4                      Canada                    North America
# 5                     Finland                   Western Europe
# 6                 Netherlands                   Western Europe
# 7                      Sweden                   Western Europe
# 8                 New Zealand        Australia and New Zealand
# 9                   Australia        Australia and New Zealand
# 10                     Israel  Middle East and Northern Africa
# 11                 Costa Rica      Latin America and Caribbean
# 12                    Austria                   Western Europe
# 13                     Mexico      Latin America and Caribbean
# ...

# %%
sns.lmplot(x="Generosity", y = 'Freedom', data = df)

# %%
sns.factorplot(x='Dystopia Residual',
               y= 'Region',
               data=df)
